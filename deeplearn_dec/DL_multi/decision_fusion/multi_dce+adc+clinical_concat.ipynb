# %%
import os
import SimpleITK as sitk
import glob
import monai
from monai.transforms import (

    AsDiscrete,
    RandAdjustContrastd,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    AddChanneld,
    SpatialPadd,
    RandRotate90d,
    RandShiftIntensityd,
    EnsureTyped,
    EnsureType,
    MapTransform,
    Resized,
    Invertd,
    ToTensord,
    NormalizeIntensityd,
    RandFlipd,
    Lambdad,
    Activations,
    AsDiscrete,
)
from monai.metrics import ROCAUCMetric
from monai.data import CacheDataset, ThreadDataLoader,DataLoader, Dataset, decollate_batch,load_decathlon_datalist
import torch
import torch.nn as  nn
from torch.nn import Linear,  Softmax
import torch.nn.functional as F
from monai.utils import first, set_determinism
from random import shuffle, seed
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('./log/tensorboard')

# %%
torch.multiprocessing.set_sharing_strategy('file_system')
set_determinism(seed=1)

# %%
# Out:
# 1598204

# %%
import pandas as pd
df_raw = pd.read_csv('判定_fill_df.csv')
df_cli = df_raw[['patient_ID', 'T_stage', 'HER2_status', 'NAC_classification', 'ER_percentage', 'PR_percentage', 'Ki_67']]

# %%
syf1_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage1/Mixed'
syf2_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage2/Mixed'
zy_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed'

syf1_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage1/Mixed'
syf2_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage2/Mixed'
zy_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed'

adc_images = sorted(glob.glob(os.path.join(syf1_adcdir,  '*.nii.gz'))) + \
             sorted(glob.glob(os.path.join(syf2_adcdir,  '*.nii.gz'))) + \
             sorted(glob.glob(os.path.join(zy_adcdir,  '*.nii.gz'))) 

dce_images = sorted(glob.glob(os.path.join(syf1_dcedir,  '*.nii.gz'))) + \
             sorted(glob.glob(os.path.join(syf2_dcedir,  '*.nii.gz'))) + \
             sorted(glob.glob(os.path.join(zy_dcedir,  '*.nii.gz')))

seed(1)
shuffle(adc_images)
seed(1)
shuffle(dce_images)

splits =  int(0.333 * len(adc_images))

train_adcimages = adc_images[splits:]
val_adcimages   = adc_images[:splits]

train_dceimages = dce_images[splits:]
val_dceimages   = dce_images[:splits]


train_clinical = []
for file_path in train_adcimages:
    p_id = file_path.split('_')[-4]
    clinical_data = df_cli[df_cli['patient_ID'] == int(p_id)].values.tolist()[0][1:]
    train_clinical.append(clinical_data)

val_clinical = []
for file_path in val_adcimages:
    p_id = file_path.split('_')[-4]
    clinical_data = df_cli[df_cli['patient_ID'] == int(p_id)].values.tolist()[0][1:]
    val_clinical.append(clinical_data)
    

train_dict = [{'image_adc': image_adc, 'image_dce': image_dce, 'clinical': clinical,  'label': int(image_adc.split('_')[-1].replace('.nii.gz', ''))} 
                  for image_adc, image_dce, clinical in zip(train_adcimages,  train_dceimages, train_clinical)]
val_dict = [{'image_adc': image_adc, 'image_dce': image_dce, 'clinical': clinical,  'label': int(image_adc.split('_')[-1].replace('.nii.gz', ''))} 
                  for image_adc, image_dce, clinical in zip(val_adcimages, val_dceimages, val_clinical)]

print(train_dict[-1])
len(train_dict), len(val_dict), len(train_dict + val_dict)
# Out:
# {'image_adc': '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage1/Mixed/2019_02_18_5096280_ADC2_0000_0.nii.gz', 'image_dce': '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage1/Mixed/2019_02_18_5096280_+C2_0000_0.nii.gz', 'clinical': [4.0, 1.0, 1.0, 0.0, 0.0, 0.4], 'label': 0}
# (438, 218, 656)

# %%
train_transforms = Compose(
        [
            LoadImaged(keys=["image_adc", "image_dce"]),
            EnsureChannelFirstd(keys=["image_adc", "image_dce"]),
            Orientationd(keys=["image_adc", 'image_dce'], axcodes="RAS"),
            Resized(keys=["image_adc"], spatial_size=(64, 64, 16)),
            Resized(keys=["image_dce"], spatial_size=(96, 96, 32)),
            
            NormalizeIntensityd(keys=["image_adc", "image_dce"], nonzero=True, channel_wise=True),
            
            RandFlipd( keys=["image_adc", ], spatial_axis=[0], prob=0.50),
            RandFlipd( keys=["image_adc", ], spatial_axis=[1], prob=0.50),
            RandFlipd( keys=["image_adc", ], spatial_axis=[2], prob=0.50),
            
            RandFlipd( keys=["image_dce", ], spatial_axis=[0], prob=0.50),
            RandFlipd( keys=["image_dce", ], spatial_axis=[1], prob=0.50),
            RandFlipd( keys=["image_dce", ], spatial_axis=[2], prob=0.50),
            
            RandRotate90d(keys=["image_adc", 'image_dce'], prob=0.50, max_k=3 ),
            RandShiftIntensityd( keys=["image_adc", 'image_dce'], offsets=0.10, prob=0.50),
            
            ToTensord(keys=['image_adc', 'image_dce','clinical',  'label'])
        ]
    )

val_transforms = Compose(
        [
            LoadImaged(keys=["image_adc",'image_dce' ]),
            EnsureChannelFirstd(keys=["image_adc", 'image_dce']),
            Orientationd(keys=["image_adc",'image_dce'], axcodes="RAS"),
            Resized(keys=["image_adc"], spatial_size=(64, 64, 16)),
            Resized(keys=["image_dce"], spatial_size=(96, 96, 32)),
            
            NormalizeIntensityd(keys=["image_adc", 'image_dce'], nonzero=True, channel_wise=True),
            ToTensord(keys=['image_adc', 'image_dce','clinical', 'label'])
        ]
    )


train_ds = CacheDataset(data=train_dict, transform=train_transforms, cache_rate=1.0, num_workers=12)
val_ds = CacheDataset(data=val_dict, transform=val_transforms, cache_rate=1.0, num_workers=12)
# Out:
# Loading dataset: 100%|███████████████████████████████████████████████████████| 438/438 [00:32<00:00, 13.48it/s]
# Loading dataset: 100%|███████████████████████████████████████████████████████| 218/218 [00:16<00:00, 13.25it/s]

# %%
# create a training data loader
train_loader = DataLoader(train_ds, batch_size=8, shuffle=True, num_workers=16, pin_memory=True)

# create a validation data loader
val_loader = DataLoader(val_ds, batch_size=8, num_workers=8, pin_memory=True)

# %%
# test_net = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False)

for i in train_loader:
    print(i['image_adc'].shape, i['image_dce'].shape)   # 测试能否正常load数据
    print(i['image_adc_meta_dict']['filename_or_obj'])
    print(i['image_dce_meta_dict']['filename_or_obj'])
    print(i['label'])
    inputs = i['image_adc']
#     outputs = test_net(inputs)
#     print(outputs.shape)
    break
# Out:
# torch.Size([8, 1, 64, 64, 16]) torch.Size([8, 1, 96, 96, 32])
# ['/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage2/Mixed/2020_10_13_5926905_ADC2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_11_29_1758843_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2022_07_09_1622444_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage2/Mixed/2015_12_16_2596649_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2020_12_09_1664718_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_06_17_1716207_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage2/Mixed/2020_09_07_4880860_ADC2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_05_17_1519342_ADC2_0000_0.nii.gz']
# ['/app/liucd/deeplearn_dec/DL_dec/data/syf_stage2/Mixed/2020_10_13_5926905_+C2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_11_29_1758843_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2022_07_09_1622444_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage2/Mixed/2015_12_16_2596649_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2020_12_09_1664718_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_06_17_1716207_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage2/Mixed/2020_09_07_4880860_+C2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_05_17_1519342_+C2_0000_0.nii.gz']
# tensor([1, 0, 0, 0, 0, 0, 1, 0])

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class DoubleTower(nn.Module):
    def __init__(self, 
                 pretrained_dce='', 
                 pretrained_adc='', 
                 device = torch.device("cuda"),
                 num_classes=2, 
                 fc_hidden_size = 128
                ):
        super().__init__()
        self.pretrained_dce = pretrained_dce
        self.pretrained_adc = pretrained_adc
        self.fc_hidden_size = fc_hidden_size
        self.num_classes = num_classes
        self.device = device
        
        self.model_dce = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
        self.model_adc = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
        
        if  pretrained_dce != '':
            dce_dict = self.model_dce.state_dict()
            dce_pretrain = torch.load(self.pretrained_dce, map_location=self.device)
            dce_pretrain_dict = {k:v for k, v in dce_pretrain.items() if  k in  dce_dict.keys()}
            dce_dict.update(dce_pretrain_dict)
            self.model_dce.load_state_dict(dce_dict)

        if  pretrained_adc !='':
            adc_dict = self.model_adc.state_dict()
            adc_pretrain = torch.load(self.pretrained_adc, map_location=self.device)
            adc_pretrain_dict = {k:v for k, v in adc_pretrain.items() if  k in  adc_dict.keys()}
            adc_dict.update(adc_pretrain_dict)
            self.model_adc.load_state_dict(adc_dict)
        
        
        # self.Linear1 = Linear(1024 + 6, self.num_classes, device=self.device) 
        self.Linear1 = Linear(1024, self.fc_hidden_size, device=self.device)  # 1024 是 所有下采样特征图globalpool之后拼接的结果        
        self.Linear2 = Linear(self.fc_hidden_size + 6, self.num_classes, device=self.device)  
        
    
    def forward(self, x1, x2, structured_data):  # x 是SegResNet的输入影像矩阵
        
        encode_output1 = self.model_dce(x1)
        encode_output2 = self.model_dce(x2)
        
        concatenated = torch.concat([encode_output1, encode_output2], dim=-1)
        
        fc1 = F.relu(self.Linear1(concatenated)) 
        fc1 = nn.Dropout(0.2)(fc1)
       
        fc2 = self.Linear2( torch.concat([fc1, structured_data], dim=-1))
        return F.log_softmax(fc2, dim=-1)

# dce_pretrain_path = '../dce_225/best_metric_model_classification3d_dict.pth'
# adc_pretrain_path = '../adc_225/best_metric_model_classification3d_dict.pth'

# device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

my_model = DoubleTower()

x1 = torch.randn(8, 1, 96, 96, 32)  # batch, channel, x, y, z
x2 = torch.randn(8, 1, 94, 64, 16)
cli = torch.randn(8, 6)
output = my_model(x1.cuda(), x2.cuda(), cli.cuda())
print('output: ', output.shape)
# Out:
# output:  torch.Size([8, 2])

# %%
dce_pretrain_path = ''
adc_pretrain_path = ''

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
model = DoubleTower(dce_pretrain_path, adc_pretrain_path, device = device)
# model = DoubleTower(device = device)

# %%
post_pred = Compose([Activations(softmax=True)])
post_label = Compose([AsDiscrete(to_onehot=2)])

loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
auc_metric = ROCAUCMetric()

# start a typical PyTorch training
val_interval = 1
best_metric = -1
best_metric_epoch = -1
max_epochs = 150
for epoch in range(max_epochs):
 
    model.train()
    epoch_loss = 0
    val_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        input_dce, input_adc, input_clinical, labels = batch_data["image_dce"].to(device), batch_data['image_adc'].to(device), batch_data["clinical"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(input_dce, input_adc, input_clinical)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_len = len(train_ds) // train_loader.batch_size

    epoch_loss /= step
    print(f"epoch {epoch + 1} average  train loss: {epoch_loss:.4f}")
    writer.add_scalar('loss/train_loss', epoch_loss, epoch)
    
    if (epoch + 1) % val_interval == 0:
       
        model.eval()
        with torch.no_grad():
            y_pred = torch.tensor([], dtype=torch.float32, device=device)
            y = torch.tensor([], dtype=torch.long, device=device)
            
            step2 = 0
            for val_data in val_loader:
                step2 += 1
                val_dce, val_adc, val_clinical, val_labels = val_data["image_dce"].to(device),val_data["image_adc"].to(device), val_data["clinical"].to(device), val_data["label"].to(device)
                val_output = model(val_dce, val_adc, val_clinical)
                y_pred = torch.cat([y_pred, val_output], dim=0)
                y = torch.cat([y, val_labels], dim=0)
                val_loss += loss_function(val_output, val_labels).item()
                
            val_loss /= step2
            writer.add_scalar('loss/val_loss', val_loss, epoch)
            acc_value = torch.eq(y_pred.argmax(dim=1), y)
            acc_metric = acc_value.sum().item() / len(acc_value)
            y_onehot = [post_label(i) for i in decollate_batch(y, detach=False)]
            y_pred_act = [post_pred(i) for i in decollate_batch(y_pred)]
            auc_metric(y_pred_act, y_onehot)
            auc_result = auc_metric.aggregate()
            auc_metric.reset()
            del y_pred_act, y_onehot
            if auc_result > best_metric:
                best_metric = auc_result
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), "best_metric_model_classification3d_dict.pth")
                print("saved new best metric model")
            print(
                "current epoch: {} current accuracy: {:.4f} current AUC: {:.4f} best accuracy: {:.4f} at epoch {}".format(
                    epoch + 1, acc_metric, auc_result, best_metric, best_metric_epoch
                )
            )
            writer.add_scalar('metric/val_Acc', acc_metric, epoch)
            writer.add_scalar('metric/val_AUC', auc_result, epoch)
            
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")
# Out:
# epoch 1 average  train loss: 0.6134
# saved new best metric model
# current epoch: 1 current accuracy: 0.6422 current AUC: 0.7447 best accuracy: 0.7447 at epoch 1
# epoch 2 average  train loss: 0.5593
# saved new best metric model
# current epoch: 2 current accuracy: 0.6422 current AUC: 0.7680 best accuracy: 0.7680 at epoch 2
# epoch 3 average  train loss: 0.5417
# saved new best metric model
# current epoch: 3 current accuracy: 0.6422 current AUC: 0.7779 best accuracy: 0.7779 at epoch 3
# epoch 4 average  train loss: 0.5395
# saved new best metric model
# current epoch: 4 current accuracy: 0.6422 current AUC: 0.8084 best accuracy: 0.8084 at epoch 4
# epoch 5 average  train loss: 0.5143
# current epoch: 5 current accuracy: 0.6422 current AUC: 0.8073 best accuracy: 0.8084 at epoch 4
# epoch 6 average  train loss: 0.5534
# current epoch: 6 current accuracy: 0.6514 current AUC: 0.7860 best accuracy: 0.8084 at epoch 4
# epoch 7 average  train loss: 0.5184
# saved new best metric model
# current epoch: 7 current accuracy: 0.6422 current AUC: 0.8396 best accuracy: 0.8396 at epoch 7
# epoch 8 average  train loss: 0.5208
# current epoch: 8 current accuracy: 0.6422 current AUC: 0.8144 best accuracy: 0.8396 at epoch 7
# epoch 9 average  train loss: 0.5020
# current epoch: 9 current accuracy: 0.6422 current AUC: 0.8283 best accuracy: 0.8396 at epoch 7
# epoch 10 average  train loss: 0.5348
# current epoch: 10 current accuracy: 0.6422 current AUC: 0.8099 best accuracy: 0.8396 at epoch 7
# epoch 11 average  train loss: 0.5182
# current epoch: 11 current accuracy: 0.6422 current AUC: 0.8076 best accuracy: 0.8396 at epoch 7
# epoch 12 average  train loss: 0.5211
# current epoch: 12 current accuracy: 0.6422 current AUC: 0.7987 best accuracy: 0.8396 at epoch 7
# epoch 13 average  train loss: 0.5018
# current epoch: 13 current accuracy: 0.6422 current AUC: 0.7869 best accuracy: 0.8396 at epoch 7
# epoch 14 average  train loss: 0.5072
# current epoch: 14 current accuracy: 0.6422 current AUC: 0.8161 best accuracy: 0.8396 at epoch 7
# epoch 15 average  train loss: 0.5019
# current epoch: 15 current accuracy: 0.6422 current AUC: 0.8104 best accuracy: 0.8396 at epoch 7
# epoch 16 average  train loss: 0.4957
# current epoch: 16 current accuracy: 0.6468 current AUC: 0.8174 best accuracy: 0.8396 at epoch 7
# epoch 17 average  train loss: 0.4902
# current epoch: 17 current accuracy: 0.6422 current AUC: 0.8083 best accuracy: 0.8396 at epoch 7
# epoch 18 average  train loss: 0.4992
# current epoch: 18 current accuracy: 0.6468 current AUC: 0.7831 best accuracy: 0.8396 at epoch 7
# epoch 19 average  train loss: 0.4834
# current epoch: 19 current accuracy: 0.6422 current AUC: 0.8115 best accuracy: 0.8396 at epoch 7
# epoch 20 average  train loss: 0.4816
# current epoch: 20 current accuracy: 0.6422 current AUC: 0.8039 best accuracy: 0.8396 at epoch 7
# epoch 21 average  train loss: 0.5056
# current epoch: 21 current accuracy: 0.6422 current AUC: 0.8202 best accuracy: 0.8396 at epoch 7
# epoch 22 average  train loss: 0.4761
# current epoch: 22 current accuracy: 0.6422 current AUC: 0.8130 best accuracy: 0.8396 at epoch 7
# epoch 23 average  train loss: 0.4683
# current epoch: 23 current accuracy: 0.6468 current AUC: 0.8133 best accuracy: 0.8396 at epoch 7
# epoch 24 average  train loss: 0.4466
# current epoch: 24 current accuracy: 0.6560 current AUC: 0.8241 best accuracy: 0.8396 at epoch 7
# epoch 25 average  train loss: 0.4795
# current epoch: 25 current accuracy: 0.6422 current AUC: 0.8079 best accuracy: 0.8396 at epoch 7
# epoch 26 average  train loss: 0.4665
# current epoch: 26 current accuracy: 0.6422 current AUC: 0.7544 best accuracy: 0.8396 at epoch 7
# epoch 27 average  train loss: 0.4802
# current epoch: 27 current accuracy: 0.6468 current AUC: 0.8162 best accuracy: 0.8396 at epoch 7
# epoch 28 average  train loss: 0.4456
# saved new best metric model
# current epoch: 28 current accuracy: 0.6560 current AUC: 0.8455 best accuracy: 0.8455 at epoch 28
# epoch 29 average  train loss: 0.4927
# current epoch: 29 current accuracy: 0.6422 current AUC: 0.8150 best accuracy: 0.8455 at epoch 28
# epoch 30 average  train loss: 0.4509
# current epoch: 30 current accuracy: 0.6376 current AUC: 0.8082 best accuracy: 0.8455 at epoch 28
# epoch 31 average  train loss: 0.4555
# current epoch: 31 current accuracy: 0.6422 current AUC: 0.8122 best accuracy: 0.8455 at epoch 28
# epoch 32 average  train loss: 0.4297
# current epoch: 32 current accuracy: 0.6560 current AUC: 0.7921 best accuracy: 0.8455 at epoch 28
# epoch 33 average  train loss: 0.4407
# current epoch: 33 current accuracy: 0.6422 current AUC: 0.7862 best accuracy: 0.8455 at epoch 28
# epoch 34 average  train loss: 0.4380
# current epoch: 34 current accuracy: 0.6514 current AUC: 0.7899 best accuracy: 0.8455 at epoch 28
# epoch 35 average  train loss: 0.4677
# current epoch: 35 current accuracy: 0.6376 current AUC: 0.8042 best accuracy: 0.8455 at epoch 28
# epoch 36 average  train loss: 0.4519
# current epoch: 36 current accuracy: 0.6422 current AUC: 0.8108 best accuracy: 0.8455 at epoch 28
# epoch 37 average  train loss: 0.4561
# current epoch: 37 current accuracy: 0.6422 current AUC: 0.8019 best accuracy: 0.8455 at epoch 28
# epoch 38 average  train loss: 0.4445
# current epoch: 38 current accuracy: 0.6330 current AUC: 0.7749 best accuracy: 0.8455 at epoch 28
# epoch 39 average  train loss: 0.4268
# current epoch: 39 current accuracy: 0.6376 current AUC: 0.8252 best accuracy: 0.8455 at epoch 28
# epoch 40 average  train loss: 0.4473
# current epoch: 40 current accuracy: 0.6468 current AUC: 0.8186 best accuracy: 0.8455 at epoch 28
# epoch 41 average  train loss: 0.4220
# current epoch: 41 current accuracy: 0.6376 current AUC: 0.8048 best accuracy: 0.8455 at epoch 28
# epoch 42 average  train loss: 0.4069
# current epoch: 42 current accuracy: 0.6422 current AUC: 0.8046 best accuracy: 0.8455 at epoch 28
# epoch 43 average  train loss: 0.4353
# current epoch: 43 current accuracy: 0.6422 current AUC: 0.8084 best accuracy: 0.8455 at epoch 28
# epoch 44 average  train loss: 0.3991
# current epoch: 44 current accuracy: 0.6376 current AUC: 0.8148 best accuracy: 0.8455 at epoch 28
# epoch 45 average  train loss: 0.4625
# current epoch: 45 current accuracy: 0.6376 current AUC: 0.7750 best accuracy: 0.8455 at epoch 28
# epoch 46 average  train loss: 0.4374
# current epoch: 46 current accuracy: 0.6468 current AUC: 0.8182 best accuracy: 0.8455 at epoch 28
# epoch 47 average  train loss: 0.4124
# current epoch: 47 current accuracy: 0.6468 current AUC: 0.7736 best accuracy: 0.8455 at epoch 28
# epoch 48 average  train loss: 0.4258
# current epoch: 48 current accuracy: 0.6514 current AUC: 0.7693 best accuracy: 0.8455 at epoch 28
# epoch 49 average  train loss: 0.3952
# current epoch: 49 current accuracy: 0.6468 current AUC: 0.7660 best accuracy: 0.8455 at epoch 28
# epoch 50 average  train loss: 0.4377
# current epoch: 50 current accuracy: 0.6376 current AUC: 0.7408 best accuracy: 0.8455 at epoch 28
# epoch 51 average  train loss: 0.3845
# current epoch: 51 current accuracy: 0.6422 current AUC: 0.7669 best accuracy: 0.8455 at epoch 28
# epoch 52 average  train loss: 0.4009
# current epoch: 52 current accuracy: 0.6376 current AUC: 0.8024 best accuracy: 0.8455 at epoch 28
# epoch 53 average  train loss: 0.4059
# current epoch: 53 current accuracy: 0.6422 current AUC: 0.7954 best accuracy: 0.8455 at epoch 28
# epoch 54 average  train loss: 0.3870
# current epoch: 54 current accuracy: 0.6468 current AUC: 0.7868 best accuracy: 0.8455 at epoch 28
# epoch 55 average  train loss: 0.3856
# current epoch: 55 current accuracy: 0.6468 current AUC: 0.7905 best accuracy: 0.8455 at epoch 28
# epoch 56 average  train loss: 0.4061
# current epoch: 56 current accuracy: 0.6422 current AUC: 0.7911 best accuracy: 0.8455 at epoch 28
# epoch 57 average  train loss: 0.3739
# current epoch: 57 current accuracy: 0.6422 current AUC: 0.7928 best accuracy: 0.8455 at epoch 28
# epoch 58 average  train loss: 0.3950
# current epoch: 58 current accuracy: 0.6422 current AUC: 0.8029 best accuracy: 0.8455 at epoch 28
# epoch 59 average  train loss: 0.3589
# current epoch: 59 current accuracy: 0.6422 current AUC: 0.7595 best accuracy: 0.8455 at epoch 28
# epoch 60 average  train loss: 0.3624
# current epoch: 60 current accuracy: 0.6560 current AUC: 0.7979 best accuracy: 0.8455 at epoch 28
# epoch 61 average  train loss: 0.3581
# current epoch: 61 current accuracy: 0.6514 current AUC: 0.7971 best accuracy: 0.8455 at epoch 28
# epoch 62 average  train loss: 0.3636
# current epoch: 62 current accuracy: 0.6468 current AUC: 0.7457 best accuracy: 0.8455 at epoch 28
# epoch 63 average  train loss: 0.3608
# current epoch: 63 current accuracy: 0.6376 current AUC: 0.7686 best accuracy: 0.8455 at epoch 28
# epoch 64 average  train loss: 0.3009
# current epoch: 64 current accuracy: 0.6422 current AUC: 0.8021 best accuracy: 0.8455 at epoch 28
# epoch 65 average  train loss: 0.3633
# current epoch: 65 current accuracy: 0.6422 current AUC: 0.7854 best accuracy: 0.8455 at epoch 28
# epoch 66 average  train loss: 0.3192
# current epoch: 66 current accuracy: 0.6422 current AUC: 0.7990 best accuracy: 0.8455 at epoch 28
# epoch 67 average  train loss: 0.3670
# current epoch: 67 current accuracy: 0.6514 current AUC: 0.7704 best accuracy: 0.8455 at epoch 28
# epoch 68 average  train loss: 0.3222
# current epoch: 68 current accuracy: 0.6468 current AUC: 0.8088 best accuracy: 0.8455 at epoch 28
# epoch 69 average  train loss: 0.3555
# current epoch: 69 current accuracy: 0.6422 current AUC: 0.7878 best accuracy: 0.8455 at epoch 28
# epoch 70 average  train loss: 0.3663
# current epoch: 70 current accuracy: 0.6422 current AUC: 0.7598 best accuracy: 0.8455 at epoch 28
# epoch 71 average  train loss: 0.3342
# current epoch: 71 current accuracy: 0.6376 current AUC: 0.8101 best accuracy: 0.8455 at epoch 28
# epoch 72 average  train loss: 0.2988
# current epoch: 72 current accuracy: 0.6468 current AUC: 0.7815 best accuracy: 0.8455 at epoch 28
# epoch 73 average  train loss: 0.3046
# current epoch: 73 current accuracy: 0.6422 current AUC: 0.7243 best accuracy: 0.8455 at epoch 28
# epoch 74 average  train loss: 0.3717
# current epoch: 74 current accuracy: 0.6422 current AUC: 0.8171 best accuracy: 0.8455 at epoch 28
# epoch 75 average  train loss: 0.2847
# current epoch: 75 current accuracy: 0.6468 current AUC: 0.7786 best accuracy: 0.8455 at epoch 28
# epoch 76 average  train loss: 0.2641
# current epoch: 76 current accuracy: 0.6422 current AUC: 0.7526 best accuracy: 0.8455 at epoch 28
# epoch 77 average  train loss: 0.2884
# current epoch: 77 current accuracy: 0.6560 current AUC: 0.7736 best accuracy: 0.8455 at epoch 28
# epoch 78 average  train loss: 0.3572
# current epoch: 78 current accuracy: 0.6606 current AUC: 0.7608 best accuracy: 0.8455 at epoch 28
# epoch 79 average  train loss: 0.2903
# saved new best metric model
# current epoch: 79 current accuracy: 0.6514 current AUC: 0.8462 best accuracy: 0.8462 at epoch 79
# epoch 80 average  train loss: 0.2816
# current epoch: 80 current accuracy: 0.6514 current AUC: 0.7529 best accuracy: 0.8462 at epoch 79
# epoch 81 average  train loss: 0.2413
# current epoch: 81 current accuracy: 0.6422 current AUC: 0.7718 best accuracy: 0.8462 at epoch 79
# epoch 82 average  train loss: 0.2568
# current epoch: 82 current accuracy: 0.6468 current AUC: 0.7696 best accuracy: 0.8462 at epoch 79
# epoch 83 average  train loss: 0.2371
# current epoch: 83 current accuracy: 0.6422 current AUC: 0.7756 best accuracy: 0.8462 at epoch 79
# epoch 84 average  train loss: 0.3071
# current epoch: 84 current accuracy: 0.6422 current AUC: 0.7818 best accuracy: 0.8462 at epoch 79
# epoch 85 average  train loss: 0.2871
# current epoch: 85 current accuracy: 0.6422 current AUC: 0.7521 best accuracy: 0.8462 at epoch 79
# epoch 86 average  train loss: 0.2522
# current epoch: 86 current accuracy: 0.6422 current AUC: 0.6959 best accuracy: 0.8462 at epoch 79
# epoch 87 average  train loss: 0.2504
# current epoch: 87 current accuracy: 0.6376 current AUC: 0.7737 best accuracy: 0.8462 at epoch 79
# epoch 88 average  train loss: 0.2775
# current epoch: 88 current accuracy: 0.6422 current AUC: 0.7187 best accuracy: 0.8462 at epoch 79
# epoch 89 average  train loss: 0.2443
# current epoch: 89 current accuracy: 0.6422 current AUC: 0.7748 best accuracy: 0.8462 at epoch 79
# epoch 90 average  train loss: 0.2106
# current epoch: 90 current accuracy: 0.6330 current AUC: 0.7227 best accuracy: 0.8462 at epoch 79
# epoch 91 average  train loss: 0.2276
# current epoch: 91 current accuracy: 0.6422 current AUC: 0.7499 best accuracy: 0.8462 at epoch 79
# epoch 92 average  train loss: 0.1661
# current epoch: 92 current accuracy: 0.6422 current AUC: 0.7686 best accuracy: 0.8462 at epoch 79
# epoch 93 average  train loss: 0.1768
# current epoch: 93 current accuracy: 0.6422 current AUC: 0.7514 best accuracy: 0.8462 at epoch 79
# epoch 94 average  train loss: 0.2585
# current epoch: 94 current accuracy: 0.6422 current AUC: 0.7782 best accuracy: 0.8462 at epoch 79
# epoch 95 average  train loss: 0.2301
# current epoch: 95 current accuracy: 0.6468 current AUC: 0.7536 best accuracy: 0.8462 at epoch 79
# epoch 96 average  train loss: 0.1772
# current epoch: 96 current accuracy: 0.6514 current AUC: 0.6912 best accuracy: 0.8462 at epoch 79
# epoch 97 average  train loss: 0.2433
# current epoch: 97 current accuracy: 0.6468 current AUC: 0.7915 best accuracy: 0.8462 at epoch 79
# epoch 98 average  train loss: 0.2501
# current epoch: 98 current accuracy: 0.6422 current AUC: 0.7538 best accuracy: 0.8462 at epoch 79
# epoch 99 average  train loss: 0.2224
# current epoch: 99 current accuracy: 0.6835 current AUC: 0.7684 best accuracy: 0.8462 at epoch 79
# epoch 100 average  train loss: 0.2106
# current epoch: 100 current accuracy: 0.6376 current AUC: 0.7500 best accuracy: 0.8462 at epoch 79
# epoch 101 average  train loss: 0.2213
# current epoch: 101 current accuracy: 0.6514 current AUC: 0.7349 best accuracy: 0.8462 at epoch 79
# epoch 102 average  train loss: 0.1727
# current epoch: 102 current accuracy: 0.6284 current AUC: 0.7037 best accuracy: 0.8462 at epoch 79
# epoch 103 average  train loss: 0.2356
# current epoch: 103 current accuracy: 0.6514 current AUC: 0.7287 best accuracy: 0.8462 at epoch 79
# epoch 104 average  train loss: 0.2169
# current epoch: 104 current accuracy: 0.6422 current AUC: 0.7332 best accuracy: 0.8462 at epoch 79
# epoch 105 average  train loss: 0.1682
# current epoch: 105 current accuracy: 0.6376 current AUC: 0.7207 best accuracy: 0.8462 at epoch 79
# epoch 106 average  train loss: 0.1913
# current epoch: 106 current accuracy: 0.6468 current AUC: 0.7128 best accuracy: 0.8462 at epoch 79
# epoch 107 average  train loss: 0.1715
# current epoch: 107 current accuracy: 0.6376 current AUC: 0.7328 best accuracy: 0.8462 at epoch 79
# epoch 108 average  train loss: 0.1756
# current epoch: 108 current accuracy: 0.6468 current AUC: 0.7227 best accuracy: 0.8462 at epoch 79
# epoch 109 average  train loss: 0.1683
# current epoch: 109 current accuracy: 0.6468 current AUC: 0.7244 best accuracy: 0.8462 at epoch 79
# epoch 110 average  train loss: 0.2163
# current epoch: 110 current accuracy: 0.6422 current AUC: 0.7414 best accuracy: 0.8462 at epoch 79
# epoch 111 average  train loss: 0.1661
# current epoch: 111 current accuracy: 0.6514 current AUC: 0.7473 best accuracy: 0.8462 at epoch 79
# epoch 112 average  train loss: 0.1811
# current epoch: 112 current accuracy: 0.6376 current AUC: 0.7183 best accuracy: 0.8462 at epoch 79
# epoch 113 average  train loss: 0.1577
# current epoch: 113 current accuracy: 0.6376 current AUC: 0.7423 best accuracy: 0.8462 at epoch 79
# epoch 114 average  train loss: 0.1109
# current epoch: 114 current accuracy: 0.6606 current AUC: 0.7020 best accuracy: 0.8462 at epoch 79
# epoch 115 average  train loss: 0.2571
# current epoch: 115 current accuracy: 0.6422 current AUC: 0.7696 best accuracy: 0.8462 at epoch 79
# epoch 116 average  train loss: 0.2140
# current epoch: 116 current accuracy: 0.6560 current AUC: 0.7326 best accuracy: 0.8462 at epoch 79
# epoch 117 average  train loss: 0.1472
# current epoch: 117 current accuracy: 0.6376 current AUC: 0.7249 best accuracy: 0.8462 at epoch 79
# epoch 118 average  train loss: 0.1512
# current epoch: 118 current accuracy: 0.6376 current AUC: 0.7068 best accuracy: 0.8462 at epoch 79
# epoch 119 average  train loss: 0.1205
# current epoch: 119 current accuracy: 0.6514 current AUC: 0.6929 best accuracy: 0.8462 at epoch 79
# epoch 120 average  train loss: 0.1353
# current epoch: 120 current accuracy: 0.6468 current AUC: 0.7160 best accuracy: 0.8462 at epoch 79
# epoch 121 average  train loss: 0.1492
# current epoch: 121 current accuracy: 0.6651 current AUC: 0.7257 best accuracy: 0.8462 at epoch 79
# epoch 122 average  train loss: 0.1517
# current epoch: 122 current accuracy: 0.6514 current AUC: 0.7276 best accuracy: 0.8462 at epoch 79
# epoch 123 average  train loss: 0.1171
# current epoch: 123 current accuracy: 0.6514 current AUC: 0.6998 best accuracy: 0.8462 at epoch 79
# epoch 124 average  train loss: 0.1505
# current epoch: 124 current accuracy: 0.6468 current AUC: 0.7315 best accuracy: 0.8462 at epoch 79
# epoch 125 average  train loss: 0.1058
# current epoch: 125 current accuracy: 0.6560 current AUC: 0.7084 best accuracy: 0.8462 at epoch 79
# epoch 126 average  train loss: 0.1478
# current epoch: 126 current accuracy: 0.6514 current AUC: 0.6991 best accuracy: 0.8462 at epoch 79
# epoch 127 average  train loss: 0.1343
# current epoch: 127 current accuracy: 0.6606 current AUC: 0.6562 best accuracy: 0.8462 at epoch 79
# epoch 128 average  train loss: 0.1233
# current epoch: 128 current accuracy: 0.6514 current AUC: 0.6974 best accuracy: 0.8462 at epoch 79
# epoch 129 average  train loss: 0.1393
# current epoch: 129 current accuracy: 0.6560 current AUC: 0.7334 best accuracy: 0.8462 at epoch 79
# epoch 130 average  train loss: 0.1483
# current epoch: 130 current accuracy: 0.6422 current AUC: 0.7364 best accuracy: 0.8462 at epoch 79
# epoch 131 average  train loss: 0.1068
# current epoch: 131 current accuracy: 0.6422 current AUC: 0.7462 best accuracy: 0.8462 at epoch 79
# epoch 132 average  train loss: 0.0994
# current epoch: 132 current accuracy: 0.6560 current AUC: 0.6788 best accuracy: 0.8462 at epoch 79
# epoch 133 average  train loss: 0.1975
# current epoch: 133 current accuracy: 0.6468 current AUC: 0.7270 best accuracy: 0.8462 at epoch 79
# epoch 134 average  train loss: 0.1837
# current epoch: 134 current accuracy: 0.6376 current AUC: 0.6819 best accuracy: 0.8462 at epoch 79
# epoch 135 average  train loss: 0.1163
# current epoch: 135 current accuracy: 0.6422 current AUC: 0.7430 best accuracy: 0.8462 at epoch 79
# epoch 136 average  train loss: 0.1039
# current epoch: 136 current accuracy: 0.6560 current AUC: 0.6745 best accuracy: 0.8462 at epoch 79
# epoch 137 average  train loss: 0.1378
# current epoch: 137 current accuracy: 0.6560 current AUC: 0.7347 best accuracy: 0.8462 at epoch 79
# epoch 138 average  train loss: 0.1497
# current epoch: 138 current accuracy: 0.6376 current AUC: 0.7386 best accuracy: 0.8462 at epoch 79
# epoch 139 average  train loss: 0.0659
# current epoch: 139 current accuracy: 0.6697 current AUC: 0.7527 best accuracy: 0.8462 at epoch 79
# epoch 140 average  train loss: 0.1310
# current epoch: 140 current accuracy: 0.6422 current AUC: 0.7249 best accuracy: 0.8462 at epoch 79
# epoch 141 average  train loss: 0.1333
# current epoch: 141 current accuracy: 0.6514 current AUC: 0.7208 best accuracy: 0.8462 at epoch 79
# epoch 142 average  train loss: 0.1255
# current epoch: 142 current accuracy: 0.6422 current AUC: 0.7351 best accuracy: 0.8462 at epoch 79
# epoch 143 average  train loss: 0.1826
# current epoch: 143 current accuracy: 0.6422 current AUC: 0.7280 best accuracy: 0.8462 at epoch 79
# epoch 144 average  train loss: 0.0937
# current epoch: 144 current accuracy: 0.6514 current AUC: 0.7606 best accuracy: 0.8462 at epoch 79
# epoch 145 average  train loss: 0.0895
# current epoch: 145 current accuracy: 0.6468 current AUC: 0.7030 best accuracy: 0.8462 at epoch 79
# epoch 146 average  train loss: 0.0623
# current epoch: 146 current accuracy: 0.6697 current AUC: 0.7448 best accuracy: 0.8462 at epoch 79
# epoch 147 average  train loss: 0.0773
# current epoch: 147 current accuracy: 0.6560 current AUC: 0.7364 best accuracy: 0.8462 at epoch 79
# epoch 148 average  train loss: 0.0795
# current epoch: 148 current accuracy: 0.6468 current AUC: 0.7655 best accuracy: 0.8462 at epoch 79
# epoch 149 average  train loss: 0.0569
# current epoch: 149 current accuracy: 0.6514 current AUC: 0.7378 best accuracy: 0.8462 at epoch 79
# epoch 150 average  train loss: 0.0519
# current epoch: 150 current accuracy: 0.6606 current AUC: 0.7400 best accuracy: 0.8462 at epoch 79
# train completed, best_metric: 0.8462 at epoch: 79

# %%
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# class DoubleTower(nn.Module):
#     def __init__(self, 
#                  pretrained_dce='', 
#                  pretrained_adc='', 
#                  device = torch.device("cuda"),
#                  num_classes=2, 
#                  fc_hidden_size = 128
#                 ):
#         super().__init__()
#         self.pretrained_dce = pretrained_dce
#         self.pretrained_adc = pretrained_adc
#         self.fc_hidden_size = fc_hidden_size
#         self.num_classes = num_classes
#         self.device = device
        
#         self.model_dce = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
#         self.model_adc = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
        
#         if  pretrained_dce != '':
#             dce_dict = self.model_dce.state_dict()
#             dce_pretrain = torch.load(self.pretrained_dce, map_location=self.device)
#             dce_pretrain_dict = {k:v for k, v in dce_pretrain.items() if  k in  dce_dict.keys()}
#             dce_dict.update(dce_pretrain_dict)
#             self.model_dce.load_state_dict(dce_dict)

#         if  pretrained_adc !='':
#             adc_dict = self.model_adc.state_dict()
#             adc_pretrain = torch.load(self.pretrained_adc, map_location=self.device)
#             adc_pretrain_dict = {k:v for k, v in adc_pretrain.items() if  k in  adc_dict.keys()}
#             adc_dict.update(adc_pretrain_dict)
#             self.model_adc.load_state_dict(adc_dict)
        
        
#         # self.Linear1 = Linear(1024, self.num_classes, device=self.device) 
#         self.Linear1 = Linear(1024, self.fc_hidden_size, device=self.device)  # 1024 是 所有下采样特征图globalpool之后拼接的结果        
#         self.Linear2 = Linear(self.fc_hidden_size + 6, self.num_classes, device=self.device)  
        
    
#     def forward(self, x1, x2, structured_data):  # x 是SegResNet的输入影像矩阵
        
#         encode_output1 = self.model_dce(x1)
#         encode_output2 = self.model_dce(x2)
        
#         concatenated = torch.concat([encode_output1, encode_output2], dim=-1)
        
#         fc1 = F.relu(self.Linear1(concatenated))
       
#         fc2 = self.Linear2( torch.concat([fc1, structured_data], dim=-1))
#         return F.log_softmax(fc2, dim=-1)

# # dce_pretrain_path = '../dce_225/best_metric_model_classification3d_dict.pth'
# # adc_pretrain_path = '../adc_225/best_metric_model_classification3d_dict.pth'

# # device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# my_model = DoubleTower()

# x1 = torch.randn(8, 1, 96, 96, 32)  # batch, channel, x, y, z
# x2 = torch.randn(8, 1, 94, 64, 16)
# cli = torch.randn(8, 6)
# output = my_model(x1.cuda(), x2.cuda(), cli.cuda())
# print('output: ', output.shape)
