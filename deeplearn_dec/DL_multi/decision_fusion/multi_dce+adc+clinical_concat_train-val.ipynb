# %%
import os
import SimpleITK as sitk
import glob
import monai
from monai.transforms import (

    AsDiscrete,
    RandAdjustContrastd,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    AddChanneld,
    SpatialPadd,
    RandRotate90d,
    RandShiftIntensityd,
    EnsureTyped,
    EnsureType,
    MapTransform,
    Resized,
    Invertd,
    ToTensord,
    NormalizeIntensityd,
    RandFlipd,
    Lambdad,
    Activations,
    AsDiscrete,
)
from monai.metrics import ROCAUCMetric
from monai.data import CacheDataset, ThreadDataLoader,DataLoader, Dataset, decollate_batch,load_decathlon_datalist
import torch
import torch.nn as  nn
from torch.nn import Linear,  Softmax
import torch.nn.functional as F
from monai.utils import first, set_determinism
from random import shuffle, seed
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('./log/tensorboard')

# %%
torch.multiprocessing.set_sharing_strategy('file_system')
set_determinism(seed=1)

# %%
import pandas as pd
df_raw = pd.read_csv('判定_fill_df.csv')
df_cli = df_raw[['patient_ID', 'T_stage', 'HER2_status', 'NAC_classification', 'ER_percentage', 'PR_percentage', 'Ki_67']]

# %%
syf1_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage1/Mixed'
syf2_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage2/Mixed'
zy_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed'
sd_adcdir = '/app/liucd/deeplearn_dec/DL_dec/data_adc/shandong/Mixed'

syf1_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage1/Mixed'
syf2_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage2/Mixed'
zy_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed'
sd_dcedir = '/app/liucd/deeplearn_dec/DL_dec/data/shandong/Mixed'



train_adcimages = sorted(glob.glob(os.path.join(syf1_adcdir,  '*.nii.gz'))) + \
                 sorted(glob.glob(os.path.join(syf2_adcdir,  '*.nii.gz'))) + \
                 sorted(glob.glob(os.path.join(zy_adcdir,  '*.nii.gz'))) 


train_dceimages = sorted(glob.glob(os.path.join(syf1_dcedir,  '*.nii.gz'))) + \
                 sorted(glob.glob(os.path.join(syf2_dcedir,  '*.nii.gz')))  + \
                 sorted(glob.glob(os.path.join(zy_dcedir,  '*.nii.gz')))

val_adcimages =  sorted(glob.glob(os.path.join(sd_adcdir,  '*.nii.gz'))) 
val_dceimages =  sorted(glob.glob(os.path.join(sd_dcedir,  '*.nii.gz')))


train_clinical = []
for file_path in train_adcimages:
    p_id = file_path.split('_')[-4]
    clinical_data = df_cli[df_cli['patient_ID'] == int(p_id)].values.tolist()[0][1:]
    train_clinical.append(clinical_data)

val_clinical = []
for file_path in val_adcimages:
    p_id = file_path.split('_')[-4]
    clinical_data = df_cli[df_cli['patient_ID'] == int(p_id)].values.tolist()[0][1:]
    val_clinical.append(clinical_data)
    

train_dict = [{'image_adc': image_adc, 'image_dce': image_dce, 'clinical': clinical,  'label': int(image_adc.split('_')[-1].replace('.nii.gz', ''))} 
                  for image_adc, image_dce, clinical in zip(train_adcimages,  train_dceimages, train_clinical)]
val_dict = [{'image_adc': image_adc, 'image_dce': image_dce, 'clinical': clinical,  'label': int(image_adc.split('_')[-1].replace('.nii.gz', ''))} 
                  for image_adc, image_dce, clinical in zip(val_adcimages, val_dceimages, val_clinical)]

print(train_dict[-1])
len(train_dict), len(val_dict), len(train_dict + val_dict)
# Out:
# {'image_adc': '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2022_10_20_1650366_ADC2_0000_0.nii.gz', 'image_dce': '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2022_10_20_1650366_+C2_0000_0.nii.gz', 'clinical': [3.0, 1.0, 2.0, 0.0, 0.0, 0.2], 'label': 0}
# (656, 225, 881)

# %%
train_transforms = Compose(
        [
            LoadImaged(keys=["image_adc", "image_dce"]),
            EnsureChannelFirstd(keys=["image_adc", "image_dce"]),
            Orientationd(keys=["image_adc", 'image_dce'], axcodes="RAS"),
            Resized(keys=["image_adc"], spatial_size=(64, 64, 16)),
            Resized(keys=["image_dce"], spatial_size=(96, 96, 32)),
            
            NormalizeIntensityd(keys=["image_adc", "image_dce"], nonzero=True, channel_wise=True),
            
            RandFlipd( keys=["image_adc", ], spatial_axis=[0], prob=0.50),
            RandFlipd( keys=["image_adc", ], spatial_axis=[1], prob=0.50),
            RandFlipd( keys=["image_adc", ], spatial_axis=[2], prob=0.50),
            
            RandFlipd( keys=["image_dce", ], spatial_axis=[0], prob=0.50),
            RandFlipd( keys=["image_dce", ], spatial_axis=[1], prob=0.50),
            RandFlipd( keys=["image_dce", ], spatial_axis=[2], prob=0.50),
            
            RandRotate90d(keys=["image_adc", 'image_dce'], prob=0.50, max_k=3 ),
            RandShiftIntensityd( keys=["image_adc", 'image_dce'], offsets=0.10, prob=0.50),
            
            ToTensord(keys=['image_adc', 'image_dce','clinical',  'label'])
        ]
    )

val_transforms = Compose(
        [
            LoadImaged(keys=["image_adc",'image_dce' ]),
            EnsureChannelFirstd(keys=["image_adc", 'image_dce']),
            Orientationd(keys=["image_adc",'image_dce'], axcodes="RAS"),
            Resized(keys=["image_adc"], spatial_size=(64, 64, 16)),
            Resized(keys=["image_dce"], spatial_size=(96, 96, 32)),
            
            NormalizeIntensityd(keys=["image_adc", 'image_dce'], nonzero=True, channel_wise=True),
            ToTensord(keys=['image_adc', 'image_dce','clinical', 'label'])
        ]
    )


train_ds = CacheDataset(data=train_dict, transform=train_transforms, cache_rate=1.0, num_workers=12)
val_ds = CacheDataset(data=val_dict, transform=val_transforms, cache_rate=1.0, num_workers=12)
# Out:
# Loading dataset: 100%|███████████████████████████████████████████████████████████████████████████████| 656/656 [00:50<00:00, 13.06it/s]
# Loading dataset: 100%|███████████████████████████████████████████████████████████████████████████████| 225/225 [00:09<00:00, 22.67it/s]

# %%
# create a training data loader
train_loader = DataLoader(train_ds, batch_size=8, shuffle=True, num_workers=16, pin_memory=True)

# create a validation data loader
val_loader = DataLoader(val_ds, batch_size=8, num_workers=8, pin_memory=True)

# %%
# test_net = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False)

for i in train_loader:
    print(i['image_adc'].shape, i['image_dce'].shape)   # 测试能否正常load数据
    print(i['image_adc_meta_dict']['filename_or_obj'])
    print(i['image_dce_meta_dict']['filename_or_obj'])
    print(i['label'])
    inputs = i['image_adc']
#     outputs = test_net(inputs)
#     print(outputs.shape)
    break
# Out:
# torch.Size([8, 1, 64, 64, 16]) torch.Size([8, 1, 96, 96, 32])
# ['/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_09_10_1741645_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_02_21_1684306_ADC2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage1/Mixed/2015_09_08_3547662_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/syf_stage2/Mixed/2021_11_17_1142656_ADC2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_6_24_1718953_ADC2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2020_04_21_1601496_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_03_09_1686787_ADC2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data_adc/zunyi/Mixed/2021_06_18_1686628_ADC2_0000_0.nii.gz']
# ['/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_09_10_1741645_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_02_21_1684306_+C2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage1/Mixed/2015_09_08_3547662_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/syf_stage2/Mixed/2021_11_17_1142656_+C2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_6_24_1718953_+C2_0000_1.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2020_04_21_1601496_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_03_09_1686787_+C2_0000_0.nii.gz', '/app/liucd/deeplearn_dec/DL_dec/data/zunyi/Mixed/2021_06_18_1686628_+C2_0000_0.nii.gz']
# tensor([0, 1, 0, 1, 1, 0, 0, 0])

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class DoubleTower(nn.Module):
    def __init__(self, 
                 pretrained_dce='', 
                 pretrained_adc='', 
                 device = torch.device("cuda"),
                 num_classes=2, 
                 fc_hidden_size = 128
                ):
        super().__init__()
        self.pretrained_dce = pretrained_dce
        self.pretrained_adc = pretrained_adc
        self.fc_hidden_size = fc_hidden_size
        self.num_classes = num_classes
        self.device = device
        
        self.model_dce = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
        self.model_adc = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
        
        if  pretrained_dce != '':
            dce_dict = self.model_dce.state_dict()
            dce_pretrain = torch.load(self.pretrained_dce, map_location=self.device)
            dce_pretrain_dict = {k:v for k, v in dce_pretrain.items() if  k in  dce_dict.keys()}
            dce_dict.update(dce_pretrain_dict)
            self.model_dce.load_state_dict(dce_dict)

        if  pretrained_adc !='':
            adc_dict = self.model_adc.state_dict()
            adc_pretrain = torch.load(self.pretrained_adc, map_location=self.device)
            adc_pretrain_dict = {k:v for k, v in adc_pretrain.items() if  k in  adc_dict.keys()}
            adc_dict.update(adc_pretrain_dict)
            self.model_adc.load_state_dict(adc_dict)
        
        
        # self.Linear1 = Linear(1024 + 6, self.num_classes, device=self.device) 
        self.Linear1 = Linear(1024, self.fc_hidden_size, device=self.device)  # 1024 是 所有下采样特征图globalpool之后拼接的结果        
        self.Linear2 = Linear(self.fc_hidden_size + 6, self.num_classes, device=self.device)  
        
    
    def forward(self, x1, x2, structured_data):  # x 是SegResNet的输入影像矩阵
        
        encode_output1 = self.model_dce(x1)
        encode_output2 = self.model_dce(x2)
        
        concatenated = torch.concat([encode_output1, encode_output2], dim=-1)
        
        fc1 = F.relu(self.Linear1(concatenated)) 
        fc1 = nn.Dropout(0.2)(fc1)
       
        fc2 = self.Linear2( torch.concat([fc1, structured_data], dim=-1))
        return F.log_softmax(fc2, dim=-1)


# device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

my_model = DoubleTower()

x1 = torch.randn(8, 1, 96, 96, 32)  # batch, channel, x, y, z
x2 = torch.randn(8, 1, 94, 64, 16)
cli = torch.randn(8, 6)
output = my_model(x1.cuda(), x2.cuda(), cli.cuda())
print('output: ', output.shape)
# Out:
# output:  torch.Size([8, 2])

# %%
# dce_pretrain_path = '/app/liucd/deeplearn_dec/DL_dec/pretrain/resnet_34.pth'
dce_pretrain_path = ''
adc_pretrain_path = ''

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
model = DoubleTower(dce_pretrain_path, adc_pretrain_path, device = device)
# model = DoubleTower(device = device)

# %%
post_pred = Compose([Activations(softmax=True)])
post_label = Compose([AsDiscrete(to_onehot=2)])

loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
auc_metric = ROCAUCMetric()

# start a typical PyTorch training
val_interval = 1
best_metric = -1
best_metric_epoch = -1
max_epochs = 150
for epoch in range(max_epochs):
 
    model.train()
    epoch_loss = 0
    val_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        input_dce, input_adc, input_clinical, labels = batch_data["image_dce"].to(device), batch_data['image_adc'].to(device), batch_data["clinical"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(input_dce, input_adc, input_clinical)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_len = len(train_ds) // train_loader.batch_size

    epoch_loss /= step
    print(f"epoch {epoch + 1} average  train loss: {epoch_loss:.4f}")
    writer.add_scalar('loss/train_loss', epoch_loss, epoch)
    
    if (epoch + 1) % val_interval == 0:
       
        model.eval()
        with torch.no_grad():
            y_pred = torch.tensor([], dtype=torch.float32, device=device)
            y = torch.tensor([], dtype=torch.long, device=device)
            
            step2 = 0
            for val_data in val_loader:
                step2 += 1
                val_dce, val_adc, val_clinical, val_labels = val_data["image_dce"].to(device),val_data["image_adc"].to(device), val_data["clinical"].to(device), val_data["label"].to(device)
                val_output = model(val_dce, val_adc, val_clinical)
                y_pred = torch.cat([y_pred, val_output], dim=0)
                y = torch.cat([y, val_labels], dim=0)
                val_loss += loss_function(val_output, val_labels).item()
                
            val_loss /= step2
            writer.add_scalar('loss/val_loss', val_loss, epoch)
            acc_value = torch.eq(y_pred.argmax(dim=1), y)
            acc_metric = acc_value.sum().item() / len(acc_value)
            y_onehot = [post_label(i) for i in decollate_batch(y, detach=False)]
            y_pred_act = [post_pred(i) for i in decollate_batch(y_pred)]
            auc_metric(y_pred_act, y_onehot)
            auc_result = auc_metric.aggregate()
            auc_metric.reset()
            del y_pred_act, y_onehot
            if auc_result > best_metric:
                best_metric = auc_result
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), "best_metric_model_classification3d_dict.pth")
                print("saved new best metric model")
            print(
                "current epoch: {} current accuracy: {:.4f} current AUC: {:.4f} best accuracy: {:.4f} at epoch {}".format(
                    epoch + 1, acc_metric, auc_result, best_metric, best_metric_epoch
                )
            )
            writer.add_scalar('metric/val_Acc', acc_metric, epoch)
            writer.add_scalar('metric/val_AUC', auc_result, epoch)
            
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")
# Out:
# epoch 1 average  train loss: 0.5824
# saved new best metric model
# current epoch: 1 current accuracy: 0.6267 current AUC: 0.6278 best accuracy: 0.6278 at epoch 1
# epoch 2 average  train loss: 0.5552
# saved new best metric model
# current epoch: 2 current accuracy: 0.6267 current AUC: 0.7015 best accuracy: 0.7015 at epoch 2
# epoch 3 average  train loss: 0.5477
# saved new best metric model
# current epoch: 3 current accuracy: 0.6267 current AUC: 0.7148 best accuracy: 0.7148 at epoch 3
# epoch 4 average  train loss: 0.5325
# current epoch: 4 current accuracy: 0.6267 current AUC: 0.6598 best accuracy: 0.7148 at epoch 3
# epoch 5 average  train loss: 0.5181
# current epoch: 5 current accuracy: 0.6267 current AUC: 0.6620 best accuracy: 0.7148 at epoch 3
# epoch 6 average  train loss: 0.5227
# current epoch: 6 current accuracy: 0.6267 current AUC: 0.6248 best accuracy: 0.7148 at epoch 3
# epoch 7 average  train loss: 0.5133
# current epoch: 7 current accuracy: 0.6267 current AUC: 0.6312 best accuracy: 0.7148 at epoch 3
# epoch 8 average  train loss: 0.5174
# current epoch: 8 current accuracy: 0.6267 current AUC: 0.6654 best accuracy: 0.7148 at epoch 3
# epoch 9 average  train loss: 0.5033
# saved new best metric model
# current epoch: 9 current accuracy: 0.6222 current AUC: 0.7158 best accuracy: 0.7158 at epoch 9
# epoch 10 average  train loss: 0.5111
# current epoch: 10 current accuracy: 0.6267 current AUC: 0.6981 best accuracy: 0.7158 at epoch 9
# epoch 11 average  train loss: 0.4889
# current epoch: 11 current accuracy: 0.6267 current AUC: 0.6962 best accuracy: 0.7158 at epoch 9
# epoch 12 average  train loss: 0.4929
# saved new best metric model
# current epoch: 12 current accuracy: 0.6311 current AUC: 0.7176 best accuracy: 0.7176 at epoch 12
# epoch 13 average  train loss: 0.4962
# current epoch: 13 current accuracy: 0.6311 current AUC: 0.7019 best accuracy: 0.7176 at epoch 12
# epoch 14 average  train loss: 0.4636
# saved new best metric model
# current epoch: 14 current accuracy: 0.6267 current AUC: 0.7179 best accuracy: 0.7179 at epoch 14
# epoch 15 average  train loss: 0.5014
# current epoch: 15 current accuracy: 0.6267 current AUC: 0.7020 best accuracy: 0.7179 at epoch 14
# epoch 16 average  train loss: 0.5113
# saved new best metric model
# current epoch: 16 current accuracy: 0.6356 current AUC: 0.7236 best accuracy: 0.7236 at epoch 16
# epoch 17 average  train loss: 0.4776
# current epoch: 17 current accuracy: 0.6267 current AUC: 0.6780 best accuracy: 0.7236 at epoch 16
# epoch 18 average  train loss: 0.5110
# saved new best metric model
# current epoch: 18 current accuracy: 0.6267 current AUC: 0.7298 best accuracy: 0.7298 at epoch 18
# epoch 19 average  train loss: 0.4679
# current epoch: 19 current accuracy: 0.6222 current AUC: 0.7243 best accuracy: 0.7298 at epoch 18
# epoch 20 average  train loss: 0.4696
# current epoch: 20 current accuracy: 0.6222 current AUC: 0.7063 best accuracy: 0.7298 at epoch 18
# epoch 21 average  train loss: 0.4650
# current epoch: 21 current accuracy: 0.6267 current AUC: 0.7217 best accuracy: 0.7298 at epoch 18
# epoch 22 average  train loss: 0.4754
# current epoch: 22 current accuracy: 0.6222 current AUC: 0.6921 best accuracy: 0.7298 at epoch 18
# epoch 23 average  train loss: 0.4661
# saved new best metric model
# current epoch: 23 current accuracy: 0.6222 current AUC: 0.7451 best accuracy: 0.7451 at epoch 23
# epoch 24 average  train loss: 0.4510
# current epoch: 24 current accuracy: 0.6222 current AUC: 0.7105 best accuracy: 0.7451 at epoch 23
# epoch 25 average  train loss: 0.4677
# current epoch: 25 current accuracy: 0.6222 current AUC: 0.6833 best accuracy: 0.7451 at epoch 23
# epoch 26 average  train loss: 0.4779
# current epoch: 26 current accuracy: 0.6178 current AUC: 0.6947 best accuracy: 0.7451 at epoch 23
# epoch 27 average  train loss: 0.4773
# current epoch: 27 current accuracy: 0.6222 current AUC: 0.7267 best accuracy: 0.7451 at epoch 23
# epoch 28 average  train loss: 0.4426
# current epoch: 28 current accuracy: 0.6311 current AUC: 0.7379 best accuracy: 0.7451 at epoch 23
# epoch 29 average  train loss: 0.4532
# current epoch: 29 current accuracy: 0.6222 current AUC: 0.6763 best accuracy: 0.7451 at epoch 23
# epoch 30 average  train loss: 0.4690
# current epoch: 30 current accuracy: 0.6267 current AUC: 0.7072 best accuracy: 0.7451 at epoch 23
# epoch 31 average  train loss: 0.4574
# current epoch: 31 current accuracy: 0.6267 current AUC: 0.7179 best accuracy: 0.7451 at epoch 23
# epoch 32 average  train loss: 0.4703
# saved new best metric model
# current epoch: 32 current accuracy: 0.6222 current AUC: 0.7470 best accuracy: 0.7470 at epoch 32
# epoch 33 average  train loss: 0.4556
# current epoch: 33 current accuracy: 0.6222 current AUC: 0.7369 best accuracy: 0.7470 at epoch 32
# epoch 34 average  train loss: 0.4536
# current epoch: 34 current accuracy: 0.6267 current AUC: 0.7116 best accuracy: 0.7470 at epoch 32
# epoch 35 average  train loss: 0.4732
# current epoch: 35 current accuracy: 0.6356 current AUC: 0.7354 best accuracy: 0.7470 at epoch 32
# epoch 36 average  train loss: 0.4505
# saved new best metric model
# current epoch: 36 current accuracy: 0.6311 current AUC: 0.7550 best accuracy: 0.7550 at epoch 36
# epoch 37 average  train loss: 0.4259
# current epoch: 37 current accuracy: 0.6356 current AUC: 0.7432 best accuracy: 0.7550 at epoch 36
# epoch 38 average  train loss: 0.4425
# current epoch: 38 current accuracy: 0.6400 current AUC: 0.7269 best accuracy: 0.7550 at epoch 36
# epoch 39 average  train loss: 0.4361
# current epoch: 39 current accuracy: 0.6533 current AUC: 0.7328 best accuracy: 0.7550 at epoch 36
# epoch 40 average  train loss: 0.4373
# current epoch: 40 current accuracy: 0.6311 current AUC: 0.7535 best accuracy: 0.7550 at epoch 36
# epoch 41 average  train loss: 0.4407
# current epoch: 41 current accuracy: 0.6311 current AUC: 0.7404 best accuracy: 0.7550 at epoch 36
# epoch 42 average  train loss: 0.4145
# current epoch: 42 current accuracy: 0.6267 current AUC: 0.7335 best accuracy: 0.7550 at epoch 36
# epoch 43 average  train loss: 0.4274
# current epoch: 43 current accuracy: 0.6267 current AUC: 0.7511 best accuracy: 0.7550 at epoch 36
# epoch 44 average  train loss: 0.4226
# current epoch: 44 current accuracy: 0.6400 current AUC: 0.7388 best accuracy: 0.7550 at epoch 36
# epoch 45 average  train loss: 0.4161
# current epoch: 45 current accuracy: 0.6356 current AUC: 0.7332 best accuracy: 0.7550 at epoch 36
# epoch 46 average  train loss: 0.4169
# current epoch: 46 current accuracy: 0.6400 current AUC: 0.7154 best accuracy: 0.7550 at epoch 36
# epoch 47 average  train loss: 0.4337
# saved new best metric model
# current epoch: 47 current accuracy: 0.6444 current AUC: 0.7598 best accuracy: 0.7598 at epoch 47
# epoch 48 average  train loss: 0.4481
# current epoch: 48 current accuracy: 0.6222 current AUC: 0.6929 best accuracy: 0.7598 at epoch 47
# epoch 49 average  train loss: 0.4030
# current epoch: 49 current accuracy: 0.6267 current AUC: 0.7457 best accuracy: 0.7598 at epoch 47
# epoch 50 average  train loss: 0.4037
# current epoch: 50 current accuracy: 0.6489 current AUC: 0.7364 best accuracy: 0.7598 at epoch 47
# epoch 51 average  train loss: 0.4278
# current epoch: 51 current accuracy: 0.6533 current AUC: 0.7479 best accuracy: 0.7598 at epoch 47
# epoch 52 average  train loss: 0.4178
# current epoch: 52 current accuracy: 0.6444 current AUC: 0.7320 best accuracy: 0.7598 at epoch 47
# epoch 53 average  train loss: 0.4227
# current epoch: 53 current accuracy: 0.6400 current AUC: 0.7139 best accuracy: 0.7598 at epoch 47
# epoch 54 average  train loss: 0.4193
# current epoch: 54 current accuracy: 0.6267 current AUC: 0.7129 best accuracy: 0.7598 at epoch 47
# epoch 55 average  train loss: 0.3741
# current epoch: 55 current accuracy: 0.6489 current AUC: 0.7291 best accuracy: 0.7598 at epoch 47
# epoch 56 average  train loss: 0.4026
# current epoch: 56 current accuracy: 0.6444 current AUC: 0.7472 best accuracy: 0.7598 at epoch 47
# epoch 57 average  train loss: 0.3839
# current epoch: 57 current accuracy: 0.6444 current AUC: 0.7347 best accuracy: 0.7598 at epoch 47
# epoch 58 average  train loss: 0.4276
# current epoch: 58 current accuracy: 0.6444 current AUC: 0.7284 best accuracy: 0.7598 at epoch 47
# epoch 59 average  train loss: 0.3887
# current epoch: 59 current accuracy: 0.6267 current AUC: 0.7392 best accuracy: 0.7598 at epoch 47
# epoch 60 average  train loss: 0.3904
# current epoch: 60 current accuracy: 0.6311 current AUC: 0.7260 best accuracy: 0.7598 at epoch 47
# epoch 61 average  train loss: 0.3998
# current epoch: 61 current accuracy: 0.6667 current AUC: 0.7200 best accuracy: 0.7598 at epoch 47
# epoch 62 average  train loss: 0.4029
# current epoch: 62 current accuracy: 0.6578 current AUC: 0.7056 best accuracy: 0.7598 at epoch 47
# epoch 63 average  train loss: 0.3919
# current epoch: 63 current accuracy: 0.6400 current AUC: 0.6991 best accuracy: 0.7598 at epoch 47
# epoch 64 average  train loss: 0.4146
# current epoch: 64 current accuracy: 0.6400 current AUC: 0.7405 best accuracy: 0.7598 at epoch 47
# epoch 65 average  train loss: 0.4043
# current epoch: 65 current accuracy: 0.6311 current AUC: 0.7137 best accuracy: 0.7598 at epoch 47
# epoch 66 average  train loss: 0.3672
# current epoch: 66 current accuracy: 0.6311 current AUC: 0.7436 best accuracy: 0.7598 at epoch 47
# epoch 67 average  train loss: 0.3958
# current epoch: 67 current accuracy: 0.6400 current AUC: 0.7010 best accuracy: 0.7598 at epoch 47
# epoch 68 average  train loss: 0.3661
# current epoch: 68 current accuracy: 0.6267 current AUC: 0.7333 best accuracy: 0.7598 at epoch 47
# epoch 69 average  train loss: 0.3905
# current epoch: 69 current accuracy: 0.6400 current AUC: 0.7215 best accuracy: 0.7598 at epoch 47
# epoch 70 average  train loss: 0.3686
# current epoch: 70 current accuracy: 0.6222 current AUC: 0.7024 best accuracy: 0.7598 at epoch 47
# epoch 71 average  train loss: 0.3409
# current epoch: 71 current accuracy: 0.6311 current AUC: 0.7169 best accuracy: 0.7598 at epoch 47
# epoch 72 average  train loss: 0.3610
# current epoch: 72 current accuracy: 0.6578 current AUC: 0.7100 best accuracy: 0.7598 at epoch 47
# epoch 73 average  train loss: 0.3763
# current epoch: 73 current accuracy: 0.6356 current AUC: 0.7220 best accuracy: 0.7598 at epoch 47
# epoch 74 average  train loss: 0.3371
# current epoch: 74 current accuracy: 0.6311 current AUC: 0.6885 best accuracy: 0.7598 at epoch 47
# epoch 75 average  train loss: 0.3474
# current epoch: 75 current accuracy: 0.6311 current AUC: 0.7273 best accuracy: 0.7598 at epoch 47
# epoch 76 average  train loss: 0.3579
# current epoch: 76 current accuracy: 0.6444 current AUC: 0.6902 best accuracy: 0.7598 at epoch 47
# epoch 77 average  train loss: 0.3543
# current epoch: 77 current accuracy: 0.6178 current AUC: 0.6604 best accuracy: 0.7598 at epoch 47
# epoch 78 average  train loss: 0.3646
# current epoch: 78 current accuracy: 0.6489 current AUC: 0.7122 best accuracy: 0.7598 at epoch 47
# epoch 79 average  train loss: 0.3386
# current epoch: 79 current accuracy: 0.6400 current AUC: 0.7278 best accuracy: 0.7598 at epoch 47
# epoch 80 average  train loss: 0.3331
# current epoch: 80 current accuracy: 0.6311 current AUC: 0.6857 best accuracy: 0.7598 at epoch 47
# epoch 81 average  train loss: 0.3304
# current epoch: 81 current accuracy: 0.6444 current AUC: 0.6922 best accuracy: 0.7598 at epoch 47
# epoch 82 average  train loss: 0.3329
# current epoch: 82 current accuracy: 0.6267 current AUC: 0.7218 best accuracy: 0.7598 at epoch 47
# epoch 83 average  train loss: 0.2989
# current epoch: 83 current accuracy: 0.6311 current AUC: 0.6998 best accuracy: 0.7598 at epoch 47
# epoch 84 average  train loss: 0.3538
# current epoch: 84 current accuracy: 0.6444 current AUC: 0.7088 best accuracy: 0.7598 at epoch 47
# epoch 85 average  train loss: 0.3462
# current epoch: 85 current accuracy: 0.6444 current AUC: 0.7142 best accuracy: 0.7598 at epoch 47
# epoch 86 average  train loss: 0.3466
# current epoch: 86 current accuracy: 0.6400 current AUC: 0.7104 best accuracy: 0.7598 at epoch 47
# epoch 87 average  train loss: 0.3044
# current epoch: 87 current accuracy: 0.6489 current AUC: 0.7002 best accuracy: 0.7598 at epoch 47
# epoch 88 average  train loss: 0.3093
# current epoch: 88 current accuracy: 0.6578 current AUC: 0.6821 best accuracy: 0.7598 at epoch 47
# epoch 89 average  train loss: 0.3165
# current epoch: 89 current accuracy: 0.6578 current AUC: 0.6970 best accuracy: 0.7598 at epoch 47
# epoch 90 average  train loss: 0.3059
# current epoch: 90 current accuracy: 0.6578 current AUC: 0.7171 best accuracy: 0.7598 at epoch 47
# epoch 91 average  train loss: 0.3298
# current epoch: 91 current accuracy: 0.6444 current AUC: 0.7483 best accuracy: 0.7598 at epoch 47
# epoch 92 average  train loss: 0.2746
# current epoch: 92 current accuracy: 0.6489 current AUC: 0.6805 best accuracy: 0.7598 at epoch 47
# epoch 93 average  train loss: 0.2802
# current epoch: 93 current accuracy: 0.6444 current AUC: 0.7101 best accuracy: 0.7598 at epoch 47
# epoch 94 average  train loss: 0.3029
# current epoch: 94 current accuracy: 0.6356 current AUC: 0.7300 best accuracy: 0.7598 at epoch 47
# epoch 95 average  train loss: 0.2897
# current epoch: 95 current accuracy: 0.6356 current AUC: 0.7291 best accuracy: 0.7598 at epoch 47
# epoch 96 average  train loss: 0.2691
# current epoch: 96 current accuracy: 0.6267 current AUC: 0.6932 best accuracy: 0.7598 at epoch 47
# epoch 97 average  train loss: 0.2537
# current epoch: 97 current accuracy: 0.6311 current AUC: 0.7049 best accuracy: 0.7598 at epoch 47
# epoch 98 average  train loss: 0.2998
# current epoch: 98 current accuracy: 0.6489 current AUC: 0.7168 best accuracy: 0.7598 at epoch 47
# epoch 99 average  train loss: 0.2618
# current epoch: 99 current accuracy: 0.6267 current AUC: 0.6821 best accuracy: 0.7598 at epoch 47
# epoch 100 average  train loss: 0.2718
# current epoch: 100 current accuracy: 0.6444 current AUC: 0.7001 best accuracy: 0.7598 at epoch 47
# epoch 101 average  train loss: 0.2816
# current epoch: 101 current accuracy: 0.6578 current AUC: 0.7183 best accuracy: 0.7598 at epoch 47
# epoch 102 average  train loss: 0.2569
# current epoch: 102 current accuracy: 0.6578 current AUC: 0.6946 best accuracy: 0.7598 at epoch 47
# epoch 103 average  train loss: 0.2783
# current epoch: 103 current accuracy: 0.6267 current AUC: 0.6807 best accuracy: 0.7598 at epoch 47
# epoch 104 average  train loss: 0.2235
# current epoch: 104 current accuracy: 0.6400 current AUC: 0.6879 best accuracy: 0.7598 at epoch 47
# epoch 105 average  train loss: 0.2680
# current epoch: 105 current accuracy: 0.6533 current AUC: 0.7265 best accuracy: 0.7598 at epoch 47
# epoch 106 average  train loss: 0.2423
# current epoch: 106 current accuracy: 0.6444 current AUC: 0.6989 best accuracy: 0.7598 at epoch 47
# epoch 107 average  train loss: 0.2435
# current epoch: 107 current accuracy: 0.6578 current AUC: 0.7152 best accuracy: 0.7598 at epoch 47
# epoch 108 average  train loss: 0.2657
# current epoch: 108 current accuracy: 0.6711 current AUC: 0.7116 best accuracy: 0.7598 at epoch 47
# epoch 109 average  train loss: 0.1984
# current epoch: 109 current accuracy: 0.6622 current AUC: 0.7053 best accuracy: 0.7598 at epoch 47
# epoch 110 average  train loss: 0.1800
# current epoch: 110 current accuracy: 0.6489 current AUC: 0.6986 best accuracy: 0.7598 at epoch 47
# epoch 111 average  train loss: 0.2490
# current epoch: 111 current accuracy: 0.6267 current AUC: 0.7062 best accuracy: 0.7598 at epoch 47
# epoch 112 average  train loss: 0.2074
# current epoch: 112 current accuracy: 0.6622 current AUC: 0.7086 best accuracy: 0.7598 at epoch 47
# epoch 113 average  train loss: 0.2039
# current epoch: 113 current accuracy: 0.6267 current AUC: 0.7156 best accuracy: 0.7598 at epoch 47
# epoch 114 average  train loss: 0.1849
# current epoch: 114 current accuracy: 0.6311 current AUC: 0.7105 best accuracy: 0.7598 at epoch 47
# epoch 115 average  train loss: 0.2312
# current epoch: 115 current accuracy: 0.6356 current AUC: 0.6902 best accuracy: 0.7598 at epoch 47
# epoch 116 average  train loss: 0.2025
# current epoch: 116 current accuracy: 0.6489 current AUC: 0.7110 best accuracy: 0.7598 at epoch 47
# epoch 117 average  train loss: 0.2101
# current epoch: 117 current accuracy: 0.6444 current AUC: 0.7125 best accuracy: 0.7598 at epoch 47
# epoch 118 average  train loss: 0.1672
# current epoch: 118 current accuracy: 0.6222 current AUC: 0.7006 best accuracy: 0.7598 at epoch 47
# epoch 119 average  train loss: 0.2031
# current epoch: 119 current accuracy: 0.6178 current AUC: 0.6893 best accuracy: 0.7598 at epoch 47
# epoch 120 average  train loss: 0.1994
# current epoch: 120 current accuracy: 0.6356 current AUC: 0.6915 best accuracy: 0.7598 at epoch 47
# epoch 121 average  train loss: 0.1772
# current epoch: 121 current accuracy: 0.6533 current AUC: 0.6615 best accuracy: 0.7598 at epoch 47
# epoch 122 average  train loss: 0.2442
# current epoch: 122 current accuracy: 0.6356 current AUC: 0.7326 best accuracy: 0.7598 at epoch 47
# epoch 123 average  train loss: 0.1896
# current epoch: 123 current accuracy: 0.6444 current AUC: 0.7034 best accuracy: 0.7598 at epoch 47
# epoch 124 average  train loss: 0.1723
# current epoch: 124 current accuracy: 0.6444 current AUC: 0.7224 best accuracy: 0.7598 at epoch 47
# epoch 125 average  train loss: 0.1795
# current epoch: 125 current accuracy: 0.6400 current AUC: 0.7096 best accuracy: 0.7598 at epoch 47
# epoch 126 average  train loss: 0.1462
# current epoch: 126 current accuracy: 0.6489 current AUC: 0.6751 best accuracy: 0.7598 at epoch 47
# epoch 127 average  train loss: 0.1354
# current epoch: 127 current accuracy: 0.6444 current AUC: 0.7007 best accuracy: 0.7598 at epoch 47
# epoch 128 average  train loss: 0.1519
# current epoch: 128 current accuracy: 0.6489 current AUC: 0.6635 best accuracy: 0.7598 at epoch 47
# epoch 129 average  train loss: 0.1699
# current epoch: 129 current accuracy: 0.6400 current AUC: 0.6918 best accuracy: 0.7598 at epoch 47
# epoch 130 average  train loss: 0.1841
# current epoch: 130 current accuracy: 0.6489 current AUC: 0.6945 best accuracy: 0.7598 at epoch 47
# epoch 131 average  train loss: 0.1062
# current epoch: 131 current accuracy: 0.6222 current AUC: 0.6110 best accuracy: 0.7598 at epoch 47
# epoch 132 average  train loss: 0.1850
# current epoch: 132 current accuracy: 0.6578 current AUC: 0.6485 best accuracy: 0.7598 at epoch 47
# epoch 133 average  train loss: 0.1284
# current epoch: 133 current accuracy: 0.6489 current AUC: 0.6627 best accuracy: 0.7598 at epoch 47
# epoch 134 average  train loss: 0.1213
# current epoch: 134 current accuracy: 0.6400 current AUC: 0.7204 best accuracy: 0.7598 at epoch 47
# epoch 135 average  train loss: 0.1615
# current epoch: 135 current accuracy: 0.6533 current AUC: 0.6852 best accuracy: 0.7598 at epoch 47
# epoch 136 average  train loss: 0.1529
# current epoch: 136 current accuracy: 0.6311 current AUC: 0.6812 best accuracy: 0.7598 at epoch 47
# epoch 137 average  train loss: 0.1476
# current epoch: 137 current accuracy: 0.6400 current AUC: 0.6885 best accuracy: 0.7598 at epoch 47
# epoch 138 average  train loss: 0.1233
# current epoch: 138 current accuracy: 0.6711 current AUC: 0.6915 best accuracy: 0.7598 at epoch 47
# epoch 139 average  train loss: 0.1354
# current epoch: 139 current accuracy: 0.6356 current AUC: 0.6807 best accuracy: 0.7598 at epoch 47
# epoch 140 average  train loss: 0.1298
# current epoch: 140 current accuracy: 0.6356 current AUC: 0.6844 best accuracy: 0.7598 at epoch 47
# epoch 141 average  train loss: 0.1197
# current epoch: 141 current accuracy: 0.6489 current AUC: 0.6666 best accuracy: 0.7598 at epoch 47
# epoch 142 average  train loss: 0.1361
# current epoch: 142 current accuracy: 0.6622 current AUC: 0.6885 best accuracy: 0.7598 at epoch 47
# epoch 143 average  train loss: 0.1287
# current epoch: 143 current accuracy: 0.6533 current AUC: 0.6568 best accuracy: 0.7598 at epoch 47
# epoch 144 average  train loss: 0.1162
# current epoch: 144 current accuracy: 0.6400 current AUC: 0.6748 best accuracy: 0.7598 at epoch 47
# epoch 145 average  train loss: 0.1402
# current epoch: 145 current accuracy: 0.6533 current AUC: 0.6838 best accuracy: 0.7598 at epoch 47
# epoch 146 average  train loss: 0.1377
# current epoch: 146 current accuracy: 0.6533 current AUC: 0.6787 best accuracy: 0.7598 at epoch 47
# epoch 147 average  train loss: 0.1353
# current epoch: 147 current accuracy: 0.6489 current AUC: 0.7229 best accuracy: 0.7598 at epoch 47
# epoch 148 average  train loss: 0.0982
# current epoch: 148 current accuracy: 0.6578 current AUC: 0.6924 best accuracy: 0.7598 at epoch 47
# epoch 149 average  train loss: 0.1010
# current epoch: 149 current accuracy: 0.6489 current AUC: 0.6968 best accuracy: 0.7598 at epoch 47
# epoch 150 average  train loss: 0.1298
# current epoch: 150 current accuracy: 0.6444 current AUC: 0.7016 best accuracy: 0.7598 at epoch 47
# train completed, best_metric: 0.7598 at epoch: 47

# %%
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# class DoubleTower(nn.Module):
#     def __init__(self, 
#                  pretrained_dce='', 
#                  pretrained_adc='', 
#                  device = torch.device("cuda"),
#                  num_classes=2, 
#                  fc_hidden_size = 128
#                 ):
#         super().__init__()
#         self.pretrained_dce = pretrained_dce
#         self.pretrained_adc = pretrained_adc
#         self.fc_hidden_size = fc_hidden_size
#         self.num_classes = num_classes
#         self.device = device
        
#         self.model_dce = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
#         self.model_adc = monai.networks.nets.resnet34(spatial_dims=3, n_input_channels=1, num_classes=2, feed_forward=False).to(self.device)
        
#         if  pretrained_dce != '':
#             dce_dict = self.model_dce.state_dict()
#             dce_pretrain = torch.load(self.pretrained_dce, map_location=self.device)
#             dce_pretrain_dict = {k:v for k, v in dce_pretrain.items() if  k in  dce_dict.keys()}
#             dce_dict.update(dce_pretrain_dict)
#             self.model_dce.load_state_dict(dce_dict)

#         if  pretrained_adc !='':
#             adc_dict = self.model_adc.state_dict()
#             adc_pretrain = torch.load(self.pretrained_adc, map_location=self.device)
#             adc_pretrain_dict = {k:v for k, v in adc_pretrain.items() if  k in  adc_dict.keys()}
#             adc_dict.update(adc_pretrain_dict)
#             self.model_adc.load_state_dict(adc_dict)
        
        
#         # self.Linear1 = Linear(1024, self.num_classes, device=self.device) 
#         self.Linear1 = Linear(1024, self.fc_hidden_size, device=self.device)  # 1024 是 所有下采样特征图globalpool之后拼接的结果        
#         self.Linear2 = Linear(self.fc_hidden_size + 6, self.num_classes, device=self.device)  
        
    
#     def forward(self, x1, x2, structured_data):  # x 是SegResNet的输入影像矩阵
        
#         encode_output1 = self.model_dce(x1)
#         encode_output2 = self.model_dce(x2)
        
#         concatenated = torch.concat([encode_output1, encode_output2], dim=-1)
        
#         fc1 = F.relu(self.Linear1(concatenated))
       
#         fc2 = self.Linear2( torch.concat([fc1, structured_data], dim=-1))
#         return F.log_softmax(fc2, dim=-1)

# # dce_pretrain_path = '../dce_225/best_metric_model_classification3d_dict.pth'
# # adc_pretrain_path = '../adc_225/best_metric_model_classification3d_dict.pth'

# # device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# my_model = DoubleTower()

# x1 = torch.randn(8, 1, 96, 96, 32)  # batch, channel, x, y, z
# x2 = torch.randn(8, 1, 94, 64, 16)
# cli = torch.randn(8, 6)
# output = my_model(x1.cuda(), x2.cuda(), cli.cuda())
# print('output: ', output.shape)
