# %%
import pandas as pd
import os
import glob

# %%
rad_path = '/app/liucd/5center-all+6clinic-pcr.csv'
df_raw = pd.read_csv(rad_path)
df_raw
# Out:
#       patient_id  dce-bl-original_shape_Elongation
# 0        1001769                          0.627809  \
# 1         976497                          0.971776
# 2         978509                          0.663658
# 3         976855                          0.623129
# 4        1580248                          0.512651
# ...          ...                               ...
# 1237     1696554                          0.696350
# 1238     1689901                          0.675386
# 1239     1510029                          0.930853
# 1240      974548                          0.890080
# 1241     1724763                          0.842615
#
#       dce-bl-original_shape_Flatness  dce-bl-original_shape_LeastAxisLength
# 0                           0.529823                              19.210830  \
# 1                           0.505614                              39.736431
# 2                           0.536511                              52.492353
# ...

# %%
pid_list = df_raw['patient_id'].tolist()

# %%
syf_dir1 = '/app/liucd/deeplearn_dec/data/syf/old/ADC'
syf_ids1 = [filename.split('_')[-3] for filename in os.listdir(syf_dir1)]

# %%
syf_dir2 = '/app/liucd/deeplearn_dec/data/syf/new/ADC'
syf_ids2 = [filename.split('_')[-3] for filename in os.listdir(syf_dir2)]

# %%
syf_ids = syf_ids1 + syf_ids2

# %%
len(syf_ids)
# Out:
# 354
