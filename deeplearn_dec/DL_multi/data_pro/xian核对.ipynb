# %%
import pandas as pd
import os
import glob

# %%
rad_path = '/app/liucd/5center-all+6clinic-pcr.csv'
df_raw = pd.read_csv(rad_path)
df_raw
# Out:
#       patient_id  dce-bl-original_shape_Elongation
# 0        1001769                          0.627809  \
# 1         976497                          0.971776
# 2         978509                          0.663658
# 3         976855                          0.623129
# 4        1580248                          0.512651
# ...          ...                               ...
# 1237     1696554                          0.696350
# 1238     1689901                          0.675386
# 1239     1510029                          0.930853
# 1240      974548                          0.890080
# 1241     1724763                          0.842615
#
#       dce-bl-original_shape_Flatness  dce-bl-original_shape_LeastAxisLength
# 0                           0.529823                              19.210830  \
# 1                           0.505614                              39.736431
# 2                           0.536511                              52.492353
# ...

# %%
pid_list = df_raw['patient_id'].tolist()

# %%
xian_dir = '/app/liucd/deeplearn_dec/data/xian/ADC'
xian_ids = [filename.split('_')[-3] for filename in os.listdir(xian_dir)]

# %%
len(xian_ids)
# Out:
# 171

# %%
not_in = [pid for pid in xian_ids if int(pid) not in pid_list]

# %%
not_in
# Out:
# ['1748411']

# %%
xian_ruzu = pd.read_excel('西安入组名单2.xlsx', header=0)['ID'].tolist()

# %%
len(xian_ruzu)
# Out:
# 176

# %%
[pid for pid in xian_ruzu if str(pid) not in xian_ids]
# Out:
# [1806755, 1748907, 1813336, 1652227, 1648701, 1803239]

# %%
add_ids = [
'1813336',
'1806755',
'1805620',
'1803239',
'1795275',
'1792453',
'1748907',
'1726635',
'1657993',
'1652227',
'1648701',
'1590306',
]

# %%
import shutil
bs_dir = '/app/liucd/deeplearn_dec/data/xian/out'

mod_name = 'DCE_label'
for filename in os.listdir(os.path.join(bs_dir, mod_name)):
    pid = filename.split('_')[-2]
    if pid not in add_ids:
        shutil.move(os.path.join(bs_dir, mod_name, filename), 
                       os.path.join(bs_dir, 'out', filename))

# %%
dir_ids = [filename.split('_')[-3] for filename in os.listdir(os.path.join(bs_dir, 'ADC')) ]

# %%
len(dir_ids)
# Out:
# 21

# %%
[pid for pid in add_ids if pid not in dir_ids]
# Out:
# []
